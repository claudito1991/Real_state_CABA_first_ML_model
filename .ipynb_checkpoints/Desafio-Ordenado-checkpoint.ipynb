# %% [markdown]
# # Modelo base de Regresión lineal

# %% [markdown]
# ### A partir de la base de datos limpia que analizamos en la etapa de EDA planteamos un primer modelo de regresión lineal

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

from sklearn.model_selection import KFold, cross_val_score
from sklearn import metrics
import numpy as np
import statsmodels.api as smf

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import GridSearchCV
import numpy as np




df = pd.read_parquet("df_completo.parquet")

# %%
df_lm_1 = df.drop(columns = "room_sin_outlier", axis =1 )
df_lm_1.dropna(subset = ["area_sin_outlier", "price_sin_outlier"], inplace = True)

# %%
df_lm_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18583 entries, 2 to 121217
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   price_sin_outlier  18583 non-null  float64
#  1   area_sin_outlier   18583 non-null  float64
#  2   place_name         18583 non-null  object
#  3   property_type      18583 non-null  object
#  4   subte_m500         18583 non-null  int64
#  5   gastro_m200        18583 non-null  int64
#  6   nuevo              18583 non-null  int64
#  7   alfrente           18583 non-null  int64
#  8   terraza            18583 non-null  int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 1.4+ MB

# %%
df_lm_1
# Out:
#         price_sin_outlier  area_sin_outlier     place_name property_type  \
# 2                 72000.0              55.0      Mataderos     apartment
# 7                138000.0              45.0       Belgrano     apartment
# 8                195000.0              65.0       Belgrano     apartment
# 16               239000.0             140.0      Mataderos            PH
# 19               350000.0             104.0        Palermo     apartment
# ...                   ...               ...            ...           ...
# 121153           165000.0              91.0   Barrio Norte     apartment
# 121158           165000.0              44.0       Recoleta     apartment
# 121160           410000.0             157.0       Belgrano     apartment
# 121209           410000.0             157.0       Belgrano     apartment
# 121217           131500.0              46.0  Villa Urquiza     apartment
#
#         subte_m500  gastro_m200  nuevo  alfrente  terraza
# 2                0            0      0         0        0
# 7                0            0      1         0        0
# 8                0            0      1         0        0
# 16               0            0      0         1        0
# 19               0            3      0         1        1
# ...            ...          ...    ...       ...      ...
# 121153           1           15      0         0        1
# 121158           1            4      0         1        0
# 121160           0            1      0         1        0
# 121209           0            1      0         1        0
# 121217           0            0      1         0        1
#
# [18583 rows x 9 columns]

# %%
df_lm_2 = pd.get_dummies(df_lm_1, columns = ["property_type", "place_name"])

# %%
df_lm_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18583 entries, 2 to 121217
# Data columns (total 73 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   price_sin_outlier                18583 non-null  float64
#  1   area_sin_outlier                 18583 non-null  float64
#  2   subte_m500                       18583 non-null  int64
#  3   gastro_m200                      18583 non-null  int64
#  4   nuevo                            18583 non-null  int64
#  5   alfrente                         18583 non-null  int64
#  6   terraza                          18583 non-null  int64
#  7   property_type_PH                 18583 non-null  uint8
#  8   property_type_apartment          18583 non-null  uint8
#  9   property_type_house              18583 non-null  uint8
#  10  property_type_store              18583 non-null  uint8
#  11  place_name_Abasto                18583 non-null  uint8
#  12  place_name_Agronomía             18583 non-null  uint8
#  13  place_name_Almagro               18583 non-null  uint8
#  14  place_name_Balvanera             18583 non-null  uint8
#  15  place_name_Barracas              18583 non-null  uint8
#  16  place_name_Barrio Norte          18583 non-null  uint8
#  17  place_name_Belgrano              18583 non-null  uint8
#  18  place_name_Boca                  18583 non-null  uint8
#  19  place_name_Boedo                 18583 non-null  uint8
#  20  place_name_Caballito             18583 non-null  uint8
#  21  place_name_Capital Federal       18583 non-null  uint8
#  22  place_name_Catalinas             18583 non-null  uint8
#  23  place_name_Centro / Microcentro  18583 non-null  uint8
#  24  place_name_Chacarita             18583 non-null  uint8
#  25  place_name_Coghlan               18583 non-null  uint8
#  26  place_name_Colegiales            18583 non-null  uint8
#  27  place_name_Congreso              18583 non-null  uint8
#  28  place_name_Constitución          18583 non-null  uint8
#  29  place_name_Flores                18583 non-null  uint8
#  30  place_name_Floresta              18583 non-null  uint8
#  31  place_name_Las Cañitas           18583 non-null  uint8
#  32  place_name_Liniers               18583 non-null  uint8
#  33  place_name_Mataderos             18583 non-null  uint8
#  34  place_name_Monserrat             18583 non-null  uint8
#  35  place_name_Monte Castro          18583 non-null  uint8
#  36  place_name_Nuñez                 18583 non-null  uint8
#  37  place_name_Once                  18583 non-null  uint8
#  38  place_name_Palermo               18583 non-null  uint8
#  39  place_name_Palermo Chico         18583 non-null  uint8
#  40  place_name_Palermo Hollywood     18583 non-null  uint8
#  41  place_name_Palermo Soho          18583 non-null  uint8
#  42  place_name_Palermo Viejo         18583 non-null  uint8
#  43  place_name_Parque Avellaneda     18583 non-null  uint8
#  44  place_name_Parque Centenario     18583 non-null  uint8
#  45  place_name_Parque Chacabuco      18583 non-null  uint8
#  46  place_name_Parque Chas           18583 non-null  uint8
#  47  place_name_Parque Patricios      18583 non-null  uint8
#  48  place_name_Paternal              18583 non-null  uint8
#  49  place_name_Pompeya               18583 non-null  uint8
#  50  place_name_Puerto Madero         18583 non-null  uint8
#  51  place_name_Recoleta              18583 non-null  uint8
#  52  place_name_Retiro                18583 non-null  uint8
#  53  place_name_Saavedra              18583 non-null  uint8
#  54  place_name_San Cristobal         18583 non-null  uint8
#  55  place_name_San Nicolás           18583 non-null  uint8
#  56  place_name_San Telmo             18583 non-null  uint8
#  57  place_name_Tribunales            18583 non-null  uint8
#  58  place_name_Velez Sarsfield       18583 non-null  uint8
#  59  place_name_Versalles             18583 non-null  uint8
#  60  place_name_Villa Crespo          18583 non-null  uint8
#  61  place_name_Villa Devoto          18583 non-null  uint8
#  62  place_name_Villa General Mitre   18583 non-null  uint8
#  63  place_name_Villa Lugano          18583 non-null  uint8
#  64  place_name_Villa Luro            18583 non-null  uint8
#  65  place_name_Villa Ortuzar         18583 non-null  uint8
#  66  place_name_Villa Pueyrredón      18583 non-null  uint8
#  67  place_name_Villa Real            18583 non-null  uint8
#  68  place_name_Villa Riachuelo       18583 non-null  uint8
#  69  place_name_Villa Santa Rita      18583 non-null  uint8
#  70  place_name_Villa Soldati         18583 non-null  uint8
#  71  place_name_Villa Urquiza         18583 non-null  uint8
#  72  place_name_Villa del Parque      18583 non-null  uint8
# dtypes: float64(2), int64(5), uint8(66)
# memory usage: 2.3 MB

# %%
#Observamos que los p-value de nuevo, terraza y al frente son altos y por esto lo sacamos del modelo. 

target_var = "price_sin_outlier"
exclude_var = ["property_type_apartment","place_name_Palermo","nuevo","terraza","alfrente"]
feature_cols = set(df_lm_2.columns.to_list()) - set([target_var]) - set(exclude_var)
feature_cols = list(feature_cols)

# %%
y = df_lm_2[target_var]
X = df_lm_2[feature_cols]


#Scaler.
scal = StandardScaler()
df2ml_palce_name_k_scaled = df_lm_2.copy()
df2ml_palce_name_k_scaled[feature_cols] = scal.fit_transform(df2ml_palce_name_k_scaled[feature_cols])

#split
X_train, X_test, y_train, y_test = train_test_split(df2ml_palce_name_k_scaled[feature_cols],
                                                    df2ml_palce_name_k_scaled[target_var],
                                                    shuffle=True, 
                                                    random_state=10)

# %%
linreg = LinearRegression()
linreg.fit(X_train,y_train)
test_pred = linreg.predict(X_test)

print ('MAE:', metrics.mean_absolute_error(y_test, test_pred))
print ('MSE:', metrics.mean_squared_error(y_test, test_pred))
print ('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, test_pred)))
print ('R2:', metrics.r2_score(y_test, test_pred))
# Out:
# MAE: 51336.101848954815
# MSE: 6806775623.065852
# RMSE: 82503.18553283777
# R2: 0.6242277958312142

# %%
prueba_df = pd.DataFrame({'True Values': y_test, 'Predicted Values': test_pred})
prueba_df.plot.scatter(x='True Values', y='Predicted Values', color = "#e85252ff")
# Out:
# <AxesSubplot:xlabel='True Values', ylabel='Predicted Values'>

# %%
pd.DataFrame({'Error Values': (y_test - test_pred)}).plot(kind = "hist", bins  = 100, color = "#e85252ff")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
coeff_df = pd.DataFrame(linreg.coef_, X_train.columns, columns=['Coefficient'])
coeff_df.reset_index(inplace = True)

df2 = {'index': "Intercept", "Coefficient":linreg.intercept_}

df_coeffs= coeff_df.append(df2, ignore_index = True)

df_coeffs
# Out:
#                            index    Coefficient
# 0               property_type_PH  -13246.360205
# 1       place_name_Palermo Chico    8352.387341
# 2               place_name_Boedo    5212.332857
# 3           place_name_San Telmo  -15113.396103
# 4           place_name_Mataderos  -13421.398780
# ..                           ...            ...
# 63  place_name_Parque Avellaneda   -6706.290370
# 64   place_name_Parque Chacabuco   -7111.132878
# 65           place_name_Paternal   -7742.967348
# 66            place_name_Liniers  -11185.084316
# 67                     Intercept  201172.076289
#
# [68 rows x 2 columns]

# %%
coeff_df.plot(kind="bar", figsize = (20,8))
# Out:
# <AxesSubplot:>

# %%
X = smf.add_constant(X_train)
mod= smf.OLS(y_train, X)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      price_sin_outlier   R-squared:                       0.650
# Model:                            OLS   Adj. R-squared:                  0.648
# Method:                 Least Squares   F-statistic:                     383.8
# Date:                Fri, 17 Sep 2021   Prob (F-statistic):               0.00
# Time:                        21:02:06   Log-Likelihood:            -1.7709e+05
# No. Observations:               13937   AIC:                         3.543e+05
# Df Residuals:                   13869   BIC:                         3.548e+05
# Df Model:                          67
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            2.012e+05    678.025    296.703      0.000       2e+05    2.03e+05
# property_type_PH                -1.325e+04    733.945    -18.048      0.000   -1.47e+04   -1.18e+04
# place_name_Palermo Chico         8352.3873    702.557     11.889      0.000    6975.280    9729.495
# place_name_Boedo                 5212.3329    721.025      7.229      0.000    3799.026    6625.639
# place_name_San Telmo            -1.511e+04    781.249    -19.345      0.000   -1.66e+04   -1.36e+04
# place_name_Mataderos            -1.342e+04    733.698    -18.293      0.000   -1.49e+04    -1.2e+04
# place_name_Parque Chas          -3358.8349    676.490     -4.965      0.000   -4684.846   -2032.824
# place_name_Villa Lugano         -1.183e+04    714.906    -16.546      0.000   -1.32e+04   -1.04e+04
# place_name_Palermo Viejo          545.8973    707.973      0.771      0.441    -841.825    1933.619
# place_name_Caballito            -1.661e+04    931.712    -17.832      0.000   -1.84e+04   -1.48e+04
# place_name_Abasto               -4937.2152    700.738     -7.046      0.000   -6310.757   -3563.673
# place_name_Villa General Mitre  -4243.5745    704.938     -6.020      0.000   -5625.348   -2861.801
# place_name_Nuñez                -3064.3780    763.505     -4.014      0.000   -4560.951   -1567.805
# place_name_Chacarita            -7469.9623    688.673    -10.847      0.000   -8819.854   -6120.070
# place_name_Capital Federal      -1.012e+04    719.992    -14.052      0.000   -1.15e+04   -8706.271
# place_name_Belgrano             -2680.6621    923.383     -2.903      0.004   -4490.618    -870.706
# place_name_Floresta             -1.397e+04    773.199    -18.062      0.000   -1.55e+04   -1.24e+04
# place_name_Constitución         -8923.6005    719.693    -12.399      0.000   -1.03e+04   -7512.905
# place_name_Tribunales           -6412.7884    665.035     -9.643      0.000   -7716.346   -5109.231
# place_name_Villa Santa Rita     -4147.5012    741.310     -5.595      0.000   -5600.568   -2694.434
# place_name_Villa Devoto         -8708.3007    746.912    -11.659      0.000   -1.02e+04   -7244.253
# place_name_Villa Soldati        -2763.9704    635.907     -4.346      0.000   -4010.435   -1517.506
# place_name_Recoleta              4313.1612    857.025      5.033      0.000    2633.277    5993.046
# place_name_Parque Centenario    -4039.1015    720.432     -5.607      0.000   -5451.245   -2626.958
# place_name_Villa Urquiza         -1.35e+04    850.412    -15.872      0.000   -1.52e+04   -1.18e+04
# place_name_Versalles            -5230.1989    651.154     -8.032      0.000   -6506.548   -3953.850
# property_type_store              5108.2444    716.773      7.127      0.000    3703.273    6513.216
# place_name_Barrio Norte         -1731.1702    806.571     -2.146      0.032   -3312.159    -150.181
# place_name_Villa Real           -5033.5894    728.794     -6.907      0.000   -6462.124   -3605.054
# place_name_Villa del Parque     -9394.7968    731.931    -12.836      0.000   -1.08e+04   -7960.113
# place_name_Villa Crespo         -1.461e+04    837.531    -17.444      0.000   -1.63e+04    -1.3e+04
# gastro_m200                      3075.2943    924.777      3.325      0.001    1262.606    4887.982
# place_name_Pompeya              -5957.1551    721.410     -8.258      0.000   -7371.216   -4543.094
# place_name_Balvanera             -1.67e+04    754.743    -22.128      0.000   -1.82e+04   -1.52e+04
# place_name_Parque Patricios     -9279.5761    741.442    -12.516      0.000   -1.07e+04   -7826.250
# place_name_Boca                 -8318.1092    702.700    -11.837      0.000   -9695.496   -6940.722
# place_name_Almagro              -1.523e+04    833.106    -18.284      0.000   -1.69e+04   -1.36e+04
# place_name_Barracas             -1.188e+04    752.322    -15.793      0.000   -1.34e+04   -1.04e+04
# place_name_Monserrat            -1.339e+04    741.439    -18.054      0.000   -1.48e+04   -1.19e+04
# place_name_Catalinas            -1095.6982    588.484     -1.862      0.063   -2249.207      57.810
# place_name_Palermo Hollywood    -2051.0147    697.681     -2.940      0.003   -3418.564    -683.465
# place_name_Villa Riachuelo      -2828.6256    679.304     -4.164      0.000   -4160.153   -1497.098
# place_name_Coghlan              -6473.6241    716.545     -9.035      0.000   -7878.148   -5069.100
# subte_m500                      -3727.4213    843.232     -4.420      0.000   -5380.269   -2074.573
# property_type_house             -1.089e+04    791.886    -13.753      0.000   -1.24e+04   -9338.216
# place_name_Velez Sarsfield      -4884.7065    668.107     -7.311      0.000   -6194.286   -3575.127
# place_name_Retiro               -2887.7781    720.043     -4.011      0.000   -4299.160   -1476.396
# place_name_Palermo Soho         -3244.8462    698.583     -4.645      0.000   -4614.163   -1875.530
# place_name_Flores                   -2e+04    850.044    -23.526      0.000   -2.17e+04   -1.83e+04
# place_name_Las Cañitas           3189.9971    731.839      4.359      0.000    1755.494    4624.500
# place_name_Saavedra             -8497.3824    758.023    -11.210      0.000   -9983.210   -7011.554
# place_name_Villa Pueyrredón     -6546.4385    725.650     -9.021      0.000   -7968.811   -5124.066
# area_sin_outlier                 9.704e+04    789.392    122.933      0.000    9.55e+04    9.86e+04
# place_name_Colegiales           -6404.2388    741.119     -8.641      0.000   -7856.932   -4951.546
# place_name_Villa Ortuzar        -4192.6961    667.525     -6.281      0.000   -5501.135   -2884.257
# place_name_Congreso             -1.084e+04    714.297    -15.180      0.000   -1.22e+04   -9442.726
# place_name_Once                 -7582.5483    683.298    -11.097      0.000   -8921.904   -6243.193
# place_name_Agronomía            -3378.5086    666.694     -5.068      0.000   -4685.318   -2071.699
# place_name_Centro / Microcentro -7798.8685    745.784    -10.457      0.000   -9260.707   -6337.030
# place_name_San Nicolás          -7955.1604    721.704    -11.023      0.000   -9369.799   -6540.522
# place_name_Villa Luro           -1.035e+04    742.031    -13.951      0.000   -1.18e+04   -8897.945
# place_name_San Cristobal        -1.063e+04    745.458    -14.257      0.000   -1.21e+04   -9166.990
# place_name_Monte Castro         -5423.3067    702.225     -7.723      0.000   -6799.762   -4046.852
# place_name_Puerto Madero         2.104e+04    715.273     29.411      0.000    1.96e+04    2.24e+04
# place_name_Parque Avellaneda    -6706.2904    656.185    -10.220      0.000   -7992.501   -5420.080
# place_name_Parque Chacabuco     -7111.1329    690.962    -10.292      0.000   -8465.512   -5756.754
# place_name_Paternal             -7742.9673    716.120    -10.812      0.000   -9146.660   -6339.275
# place_name_Liniers              -1.119e+04    713.633    -15.673      0.000   -1.26e+04   -9786.267
# ==============================================================================
# Omnibus:                     5377.738   Durbin-Watson:                   2.018
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            53514.097
# Skew:                           1.571   Prob(JB):                         0.00
# Kurtosis:                      12.071   Cond. No.                         4.85
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\Claudio\anaconda3\envs\dhdsblend2021_geopandas\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# # Reducción de dimensionalidad con K-means

# %% [markdown]
# #### Se plantea un algoritmo no supervisado para tratar de agrupar barrios similares y de esta forma bajar la dimensionalidad y tratar de mejorar el scoring del modelo. Para esto se define la columna price_m2 para hacer este agrupamiento

# %%
df["price_m2"] = df["price_sin_outlier"] / df["area_sin_outlier"]

# %%
#----------- Kmeans ------------
df_coun_price_place=df.groupby("place_name").agg(conteo = ('area_sin_outlier',lambda x: len(x)/df.shape[0]),precio_medio = ('price_m2','median'))
df_coun_price_place.head()

inertias = []
for x in range(1,21):
    kmeans = KMeans(n_clusters=x,random_state=1457).fit(df_coun_price_place)
    inertias.append(kmeans.inertia_)
    
plt.plot(list(range(1,21)),inertias)

kmeans_fit = KMeans(n_clusters = 4,random_state=1457).fit(df_coun_price_place)
df_coun_price_place["group"] = kmeans_fit.labels_
df_coun_price_place.reset_index(inplace=True)

# %%
df_groups = df.merge(df_coun_price_place[["place_name","group"]],on=["place_name"],how = "left")
df_groups = pd.get_dummies(df_groups, columns = ["property_type", "place_name", "group"])

# %%
df_groups_sin_room = df_groups.drop(columns = "room_sin_outlier", axis =1 )

# %%
df_groups_sin_room.dropna(subset = ["area_sin_outlier", "price_sin_outlier"], inplace = True)

# %%
target_var = "price_sin_outlier"
exclude_var = ["price_m2", "place_name","group_0","property_type_apartment","group_ordinal"]
feature_cols = set(df_lm_2.columns.to_list()) - set([target_var]) - set(exclude_var)
feature_cols = list(feature_cols)

# %%
feature_cols_area_groups_ordinal_property = ["area_sin_outlier", "group_1","group_2","group_3","property_type_house","property_type_PH","property_type_store","nuevo"]

# %%
y = df_groups_sin_room[target_var]
X = df_groups_sin_room[feature_cols]

# %%
#Acá no se usa el train-test-split porque eso lo hace ya el crossval no?


cv = KFold(n_splits=10, random_state=1, shuffle=True)
model = LinearRegression()

scores = cross_val_score(model, X, y, cv=cv, n_jobs=-1)

# %%
scores
# Out:
# array([0.63856589, 0.66064839, 0.65355233, 0.61782283, 0.61332388,
#        0.61469785, 0.65898682, 0.66817136, 0.63093661, 0.65451672])

# %%
scores.mean()
# Out:
# 0.6411222674142742

# %%
#No se bien que me falta acá o cuándo nos dimos cuenta de que este modelo no funcionaba por el Data Leakeage

# %% [markdown]
# # Se plantea un modelo penalizado Ridge para mejorar el modelo baseline que tenemos

# %% [markdown]
# ### El modelo K-means si bien mejora un poco el score está conceptualmente mal ya que hay un data leakeage de price_m2 por tener la variable target metida dentro

# %%
#Acá tomamos el mismo dataframe que en baseline. Sin grupos de barrios, barrios sin outliers, rooms sin ouliers y price sin outliers

y = df_lm_2[target_var]
X = df_lm_2[feature_cols]

# %%
ridge_alphas = np.linspace(0, 10000, 100)
ridge = linear_model.Ridge()
grid = dict()
grid['alpha'] = ridge_alphas
gscv = GridSearchCV( \
    ridge, grid, scoring='r2', \
    cv=cv, n_jobs=-1)

results_ridge = gscv.fit(X, y)

#Acá no es necesario hacer el split train test tampoco?

# %%
results_ridge_df = pd.DataFrame(results_ridge.cv_results_)
results_ridge_df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0       0.399469      0.268579         0.010047        0.007304         0.0
# 1       0.093336      0.029019         0.014154        0.014745  101.010101
# 2       0.061161      0.014883         0.007697        0.004449  202.020202
# 3       0.051717      0.017295         0.006175        0.002698  303.030303
# 4       0.045897      0.003852         0.005004        0.000889  404.040404
#
#                           params  split0_test_score  split1_test_score  \
# 0                 {'alpha': 0.0}           0.638561           0.660632
# 1  {'alpha': 101.01010101010101}           0.621604           0.645090
# 2  {'alpha': 202.02020202020202}           0.605750           0.629434
# 3    {'alpha': 303.030303030303}           0.593237           0.616929
# 4  {'alpha': 404.04040404040404}           0.583120           0.606780
#
#    split2_test_score  split3_test_score  split4_test_score  split5_test_score  \
# 0           0.653552           0.617738           0.613318           0.614701
# 1           0.637996           0.601571           0.594502           0.599979
# 2           0.622945           0.586541           0.579295           0.586676
# 3           0.611125           0.574640           0.567661           0.575967
# 4           0.601554           0.564978           0.558323           0.567113
#
#    split6_test_score  split7_test_score  split8_test_score  split9_test_score  \
# 0           0.658987           0.668171           0.630937           0.654504
# 1           0.647535           0.656075           0.613940           0.653203
# 2           0.633198           0.643075           0.599045           0.643231
# 3           0.621497           0.632280           0.587505           0.634110
# 4           0.611839           0.623273           0.578203           0.626220
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.641110        0.019731                1
# 1         0.627150        0.022437                2
# 2         0.612919        0.023177                3
# 3         0.601495        0.023503                4
# 4         0.592140        0.023675                5

# %%
#Como alfa es cero el modelo de regresión lineal que calculamos como base queda sin modificarse. 
results_ridge.best_params_
# Out:
# {'alpha': 0.0}

# %%
results_ridge.best_score_
# Out:
# 0.6411101540335916

# %% [markdown]
# # Como el modelo predice con poca capacidad pretendemos mejorar el mismo agregando un campo más que sea el ingreso medio por comuna.

# %% [markdown]
# ### para esto importamos un dataset nuevo que son las comunas de CABA y pretendemos cruzar los datos entre estas bases y mejorar la performance del mismo

# %%
import geopandas as gpd

filename = "CABA_comunas.geojson"
file = open(filename, encoding ="utf8")
geo_comuna = gpd.read_file(file)
geo_comuna = geo_comuna.set_crs("epsg:5349", allow_override = True)
geo_comuna.head()
# Out:
#                                                  WKT ID          OBJETO  \
# 0  MULTIPOLYGON (((-58.3800038855693 -34.57002352...  1  LIMITE COMUNAL
# 1  MULTIPOLYGON (((-58.4306058283309 -34.60704708...  3  LIMITE COMUNAL
# 2  MULTIPOLYGON (((-58.4883373673246 -34.62016035...  6  LIMITE COMUNAL
# 3  MULTIPOLYGON (((-58.498384839883 -34.596367656...  7  LIMITE COMUNAL
# 4  MULTIPOLYGON (((-58.5033113250844 -34.59385615...  8  LIMITE COMUNAL
#
#           COMUNAS                                            BARRIOS  \
# 0   2.00000000000                                           RECOLETA
# 1   6.00000000000                                          CABALLITO
# 2  10.00000000000  FLORESTA - MONTE CASTRO - VELEZ SARSFIELD - VE...
# 3  11.00000000000  VILLA DEL PARQUE - VILLA  DEVOTO - VILLA GRAL....
# 4  12.00000000000  COGHLAN - SAAVEDRA - VILLA PUEYRREDON - VILLA ...
#
#            PERIMETRO                  AREA  \
# 0  21452.83864780000   6317264.56099000107
# 1  10990.96447150000   6851028.91356999893
# 2  18332.03745670000  12656556.93779999949
# 3  19987.69615500000  14120042.42380000092
# 4  17232.18937200000  15570926.63759999909
#
#                                             geometry
# 0  MULTIPOLYGON (((-58.38000 -34.57002, -58.38002...
# 1  MULTIPOLYGON (((-58.43061 -34.60705, -58.43056...
# 2  MULTIPOLYGON (((-58.48834 -34.62016, -58.48820...
# 3  MULTIPOLYGON (((-58.49838 -34.59637, -58.49718...
# 4  MULTIPOLYGON (((-58.50331 -34.59386, -58.50347...

# %%
import geopandas as gpd
import pandas as pd
geo_caba = pd.read_parquet("geo_caba_mod.parquet")
geo_caba = gpd.GeoDataFrame(geo_caba, geometry = gpd.points_from_xy(geo_caba.lon, geo_caba.lat))
geo_caba.head()

geo_caba = geo_caba.set_crs("epsg:5349", allow_override = True)

# %%
def lock_comuna(propiedad):
    try:
        mask = geo_comuna.contains(propiedad)
        return int(float(geo_comuna.loc[mask, "COMUNAS"].values[0]))
    except:
        pass

# %%
geo_caba["comunas"] = geo_caba["geometry"].apply(lambda x: lock_comuna(x))

# %%
geo_caba_modelo = geo_caba.copy()

# %%
geo_caba_modelo = geo_caba_modelo.dropna(subset = ["comunas"])

# %%
geo_caba_modelo.shape
# Out:
# (21953, 82)

# %%
geo_caba["geometry"].head()
# Out:
# 0     POINT (-58.50884 -34.66182)
# 2     POINT (-58.52298 -34.65226)
# 7     POINT (-58.44336 -34.55987)
# 8     POINT (-58.44336 -34.55987)
# 16    POINT (-58.50162 -34.65236)
# Name: geometry, dtype: geometry

# %%
diccionario = {1:72681,
2:75944,
3:48715,
4:47606,
5:58941,
6:69510,
7:60252,
8:49424,
9:53797,
10:64337,
11:62991,
12:76005,
13:80052,
14:85061,
15:63423}

# %%
geo_caba_modelo["ingreso_medio_comuna"] = geo_caba_modelo["comunas"].map(diccionario)

# %%
geo_caba_modelo_df= pd.DataFrame(geo_caba_modelo)

# %%
geo_caba_modelo_df = pd.get_dummies(geo_caba_modelo_df,columns = ["comunas"], prefix = "comuna")

# %%
geo_caba_modelo_df
# Out:
#        property_type        lat        lon  price_parseado  room_parseada  \
# 0                 PH -34.661824 -58.508839         62000.0            NaN
# 2          apartment -34.652262 -58.522982         72000.0            NaN
# 7          apartment -34.559873 -58.443362        138000.0            1.0
# 8          apartment -34.559873 -58.443362        195000.0            NaN
# 16                PH -34.652356 -58.501624        239000.0            4.0
# ...              ...        ...        ...             ...            ...
# 121153     apartment -34.599214 -58.402519        165000.0            NaN
# 121158     apartment -34.587425 -58.397372        165000.0            1.0
# 121160     apartment -34.563685 -58.442683        410000.0            NaN
# 121209     apartment -34.563685 -58.442683        410000.0            NaN
# 121217     apartment -34.570639 -58.475596        131500.0            1.0
#
#         area_completa                                        description  \
# 0                55.0  2 ambientes tipo casa planta baja por pasillo,...
# 2                55.0  2 ambientes 3er piso lateral living comedor am...
# 7                45.0  excelente monoambiente a estrenar amplio super...
# 8                65.0  excelente dos ambientes  estrenar amplio super...
# 16              140.0  ventas mataderos al frente duplex 4 amb.- plan...
# ...               ...                                                ...
# 121153           91.0  excelente departamento con terraza propia y pa...
# 121158           44.0  excelente ubicación - avenida pueyrredon y las...
# 121160          157.0  edificio en esquina de muy buena categoría de ...
# 121209          157.0  edificio en esquina de muy buena categoría de ...
# 121217           46.0  venta departamento ambiente divisible a estren...
#
#         nuevo  terraza  alfrente  ...  comuna_6.0  comuna_7.0  comuna_8.0  \
# 0           0        0         0  ...           0           0           0
# 2           0        0         0  ...           0           0           0
# 7           1        0         0  ...           0           0           0
# 8           1        0         0  ...           0           0           0
# 16          0        0         1  ...           0           0           0
# ...       ...      ...       ...  ...         ...         ...         ...
# 121153      0        1         0  ...           0           0           0
# 121158      0        0         1  ...           0           0           0
# 121160      0        0         1  ...           0           0           0
# 121209      0        0         1  ...           0           0           0
# 121217      1        1         0  ...           0           0           0
#
#         comuna_9.0  comuna_10.0 comuna_11.0  comuna_12.0  comuna_13.0  \
# 0                1            0           0            0            0
# 2                1            0           0            0            0
# 7                0            0           0            0            1
# 8                0            0           0            0            1
# 16               1            0           0            0            0
# ...            ...          ...         ...          ...          ...
# 121153           0            0           0            0            0
# 121158           0            0           0            0            0
# 121160           0            0           0            0            0
# 121209           0            0           0            0            0
# 121217           0            0           0            1            0
#
#         comuna_14.0  comuna_15.0
# 0                 0            0
# 2                 0            0
# 7                 0            0
# 8                 0            0
# 16                0            0
# ...             ...          ...
# 121153            0            0
# 121158            0            0
# 121160            1            0
# 121209            1            0
# 121217            0            0
#
# [21953 rows x 97 columns]
